# %%
# pip install pandas scikit-learn matplotlib seaborn

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from keras.models import Sequential
from keras.layers import *
from keras.utils import *
from keras.optimizers import *
from keras.callbacks import *
from keras.metrics import *
from tensorflow.keras import initializers
from tensorflow.keras.layers import GRU

import pandas as pd
import numpy as np
from datetime import datetime

from collections import *
from sklearn.utils import *

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
### import the data
news_data = pd.read_csv("../../data/apple_news_aggregated.csv")
news_data.head()
# Out:
#          date  negative  neutral  positive
# 0  2018-01-01         0        2         0
# 1  2018-01-02         1        9         0
# 2  2018-01-03         3        4         0
# 3  2018-01-04         2        3         1
# 4  2018-01-05         3        2         0

# %%
### import the data
stock_data = pd.read_csv("../../data/stock_data_final_2018_2025.csv")
stock_data.head()
# Out:
#          date       open       high        low      close       volume  \
# 0  2018-01-01  42.630001  42.647499  42.305000  42.307499  103999600.0
# 1  2018-01-02  42.540001  43.075001  42.314999  43.064999  102223600.0
# 2  2018-01-03  43.132500  43.637501  42.990002  43.057499  118071600.0
# 3  2018-01-04  43.134998  43.367500  43.020000  43.257500   89738400.0
# 4  2018-01-05  43.360001  43.842499  43.262501  43.750000   94640000.0
#
#        sma_5     sma_20     ema_12     ema_26        rsi      macd  \
# 0  42.399999  43.199125  42.778539  42.940969  36.626383 -0.162430
# 1  42.458999  43.199000  42.822609  42.950156  51.991143 -0.127547
# 2  42.608999  43.199125  42.858746  42.958108  51.857092 -0.099361
# 3  42.798999  43.187374  42.920093  42.980285  55.176213 -0.060192
# 4  43.087499  43.200249  43.047771  43.037301  62.104664  0.010470
#
#    macd_signal  upper_Band  lower_Band    stoch_k    stoch_d       atr  \
# 0     0.006934   44.379324   42.018926   0.132489   2.182314  0.480331
# 1    -0.019962   44.379255   42.018744  14.992662   5.083465  0.500843
# 2    -0.035842   44.379319   42.018930  29.705782  14.943644  0.511319
# 3    -0.040712   44.360309   42.014440  50.140658  31.613034  0.499617
# 4    -0.030475   44.391804   42.008695  66.314014  48.720151  0.505716
#
#          adx
# 0  20.496033
# 1  19.296351
# 2  18.983802
# 3  18.693577
# 4  19.332961

# %%
stock_with_sentiment_data = pd.merge(stock_data, news_data, left_on='date', right_on='date', how='left')
stock_with_sentiment_data.head()
# Out:
#          date       open       high        low      close       volume  \
# 0  2018-01-01  42.630001  42.647499  42.305000  42.307499  103999600.0
# 1  2018-01-02  42.540001  43.075001  42.314999  43.064999  102223600.0
# 2  2018-01-03  43.132500  43.637501  42.990002  43.057499  118071600.0
# 3  2018-01-04  43.134998  43.367500  43.020000  43.257500   89738400.0
# 4  2018-01-05  43.360001  43.842499  43.262501  43.750000   94640000.0
#
#        sma_5     sma_20     ema_12     ema_26  ...  macd_signal  upper_Band  \
# 0  42.399999  43.199125  42.778539  42.940969  ...     0.006934   44.379324
# 1  42.458999  43.199000  42.822609  42.950156  ...    -0.019962   44.379255
# 2  42.608999  43.199125  42.858746  42.958108  ...    -0.035842   44.379319
# 3  42.798999  43.187374  42.920093  42.980285  ...    -0.040712   44.360309
# 4  43.087499  43.200249  43.047771  43.037301  ...    -0.030475   44.391804
#
#    lower_Band    stoch_k    stoch_d       atr        adx  negative  neutral  \
# 0   42.018926   0.132489   2.182314  0.480331  20.496033         0        2
# 1   42.018744  14.992662   5.083465  0.500843  19.296351         1        9
# 2   42.018930  29.705782  14.943644  0.511319  18.983802         3        4
# 3   42.014440  50.140658  31.613034  0.499617  18.693577         2        3
# 4   42.008695  66.314014  48.720151  0.505716  19.332961         3        2
#
#    positive
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#
# [5 rows x 22 columns]

# %%
stock_with_sentiment_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'sma_5', 'sma_20',
#        'ema_12', 'ema_26', 'rsi', 'macd', 'macd_signal', 'upper_Band',
#        'lower_Band', 'stoch_k', 'stoch_d', 'atr', 'adx', 'negative', 'neutral',
#        'positive'],
#       dtype='object')

# %%
stock_with_sentiment_data['target_close'] = stock_with_sentiment_data['close'].shift(-1)
stock_with_sentiment_data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
# 2677  2025-05-01  209.080002  214.559998  208.899994  213.320007   57365700.0
#
#            sma_5      sma_20      ema_12      ema_26  ...  upper_Band  \
# 0      42.399999   43.199125   42.778539   42.940969  ...   44.379324
# 1      42.458999   43.199000   42.822609   42.950156  ...   44.379255
# 2      42.608999   43.199125   42.858746   42.958108  ...   44.379319
# 3      42.798999   43.187374   42.920093   42.980285  ...   44.360309
# 4      43.087499   43.200249   43.047771   43.037301  ...   44.391804
# ...          ...         ...         ...         ...  ...         ...
# 2673  208.162000  198.834999  203.637482  203.551848  ...  215.043319
# 2674  209.269998  200.720999  204.637870  204.039859  ...  212.318059
# 2675  209.838000  201.338999  205.648968  204.570981  ...  213.759460
# 2676  210.482001  202.442999  206.702973  205.158316  ...  214.709264
# 2677  211.290002  203.201500  207.720978  205.762886  ...  216.168220
#
#       lower_Band    stoch_k    stoch_d       atr        adx  negative  \
# 0      42.018926   0.132489   2.182314  0.480331  20.496033         0
# 1      42.018744  14.992662   5.083465  0.500843  19.296351         1
# 2      42.018930  29.705782  14.943644  0.511319  18.983802         3
# 3      42.014440  50.140658  31.613034  0.499617  18.693577         2
# 4      42.008695  66.314014  48.720151  0.505716  19.332961         3
# ...          ...        ...        ...       ...        ...       ...
# 2673  182.626679  85.648072  83.804139  8.008324  21.354716         1
# 2674  189.123939  88.096709  86.333407  7.724872  20.815254         4
# 2675  188.918539  91.104717  88.283166  7.449524  20.435112         5
# 2676  190.176735  94.864740  91.355389  7.410987  19.700269         4
# 2677  190.234780  95.284777  93.751412  7.285917  19.197194        19
#
#       neutral  positive  target_close
# 0           2         0     43.064999
# 1           9         0     43.057499
# 2           4         0     43.257500
# 3           3         1     43.750000
# 4           2         0     43.750000
# ...       ...       ...           ...
# 2673        0         3    210.139999
# 2674        3         4    211.210007
# 2675        3         0    212.500000
# 2676       11         3    213.320007
# 2677       19         6           NaN
#
# [2678 rows x 23 columns]

# %%
stock_with_sentiment_data = stock_with_sentiment_data.drop([2677])
stock_with_sentiment_data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2672  2025-04-26  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
#
#            sma_5      sma_20      ema_12      ema_26  ...  upper_Band  \
# 0      42.399999   43.199125   42.778539   42.940969  ...   44.379324
# 1      42.458999   43.199000   42.822609   42.950156  ...   44.379255
# 2      42.608999   43.199125   42.858746   42.958108  ...   44.379319
# 3      42.798999   43.187374   42.920093   42.980285  ...   44.360309
# 4      43.087499   43.200249   43.047771   43.037301  ...   44.391804
# ...          ...         ...         ...         ...  ...         ...
# 2672  206.254001  197.443999  202.611570  203.093596  ...  214.576675
# 2673  208.162000  198.834999  203.637482  203.551848  ...  215.043319
# 2674  209.269998  200.720999  204.637870  204.039859  ...  212.318059
# 2675  209.838000  201.338999  205.648968  204.570981  ...  213.759460
# 2676  210.482001  202.442999  206.702973  205.158316  ...  214.709264
#
#       lower_Band    stoch_k    stoch_d       atr        adx  negative  \
# 0      42.018926   0.132489   2.182314  0.480331  20.496033         0
# 1      42.018744  14.992662   5.083465  0.500843  19.296351         1
# 2      42.018930  29.705782  14.943644  0.511319  18.983802         3
# 3      42.014440  50.140658  31.613034  0.499617  18.693577         2
# 4      42.008695  66.314014  48.720151  0.505716  19.332961         3
# ...          ...        ...        ...       ...        ...       ...
# 2672  180.311324  85.255441  80.031103  8.351271  22.240426         5
# 2673  182.626679  85.648072  83.804139  8.008324  21.354716         1
# 2674  189.123939  88.096709  86.333407  7.724872  20.815254         4
# 2675  188.918539  91.104717  88.283166  7.449524  20.435112         5
# 2676  190.176735  94.864740  91.355389  7.410987  19.700269         4
#
#       neutral  positive  target_close
# 0           2         0     43.064999
# 1           9         0     43.057499
# 2           4         0     43.257500
# 3           3         1     43.750000
# 4           2         0     43.750000
# ...       ...       ...           ...
# 2672       12         8    209.279999
# 2673        0         3    210.139999
# 2674        3         4    211.210007
# 2675        3         0    212.500000
# 2676       11         3    213.320007
#
# [2677 rows x 23 columns]

# %%
stock_with_sentiment_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'sma_5', 'sma_20',
#        'ema_12', 'ema_26', 'rsi', 'macd', 'macd_signal', 'upper_Band',
#        'lower_Band', 'stoch_k', 'stoch_d', 'atr', 'adx', 'negative', 'neutral',
#        'positive', 'target_close'],
#       dtype='object')

# %% [markdown]
# ## correlation

# %%
### select the features to work on
Data = stock_with_sentiment_data.copy()
Data = Data[['date',
             'open',
             'high',
             'low',
             'close',
             'volume',
             'sma_5', 'sma_20',
             'ema_12', 'ema_26', 
             'rsi', 
             'macd', 'macd_signal', 
             'upper_Band','lower_Band', 
             'stoch_k', 'stoch_d', 
             'atr', 'adx',
             'negative', 'neutral', 'positive',
             'target_close'
            ]]

Data = Data.sort_values(['date'])
Data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2672  2025-04-26  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
#
#            sma_5      sma_20      ema_12      ema_26  ...  upper_Band  \
# 0      42.399999   43.199125   42.778539   42.940969  ...   44.379324
# 1      42.458999   43.199000   42.822609   42.950156  ...   44.379255
# 2      42.608999   43.199125   42.858746   42.958108  ...   44.379319
# 3      42.798999   43.187374   42.920093   42.980285  ...   44.360309
# 4      43.087499   43.200249   43.047771   43.037301  ...   44.391804
# ...          ...         ...         ...         ...  ...         ...
# 2672  206.254001  197.443999  202.611570  203.093596  ...  214.576675
# 2673  208.162000  198.834999  203.637482  203.551848  ...  215.043319
# 2674  209.269998  200.720999  204.637870  204.039859  ...  212.318059
# 2675  209.838000  201.338999  205.648968  204.570981  ...  213.759460
# 2676  210.482001  202.442999  206.702973  205.158316  ...  214.709264
#
#       lower_Band    stoch_k    stoch_d       atr        adx  negative  \
# 0      42.018926   0.132489   2.182314  0.480331  20.496033         0
# 1      42.018744  14.992662   5.083465  0.500843  19.296351         1
# 2      42.018930  29.705782  14.943644  0.511319  18.983802         3
# 3      42.014440  50.140658  31.613034  0.499617  18.693577         2
# 4      42.008695  66.314014  48.720151  0.505716  19.332961         3
# ...          ...        ...        ...       ...        ...       ...
# 2672  180.311324  85.255441  80.031103  8.351271  22.240426         5
# 2673  182.626679  85.648072  83.804139  8.008324  21.354716         1
# 2674  189.123939  88.096709  86.333407  7.724872  20.815254         4
# 2675  188.918539  91.104717  88.283166  7.449524  20.435112         5
# 2676  190.176735  94.864740  91.355389  7.410987  19.700269         4
#
#       neutral  positive  target_close
# 0           2         0     43.064999
# 1           9         0     43.057499
# 2           4         0     43.257500
# 3           3         1     43.750000
# 4           2         0     43.750000
# ...       ...       ...           ...
# 2672       12         8    209.279999
# 2673        0         3    210.139999
# 2674        3         4    211.210007
# 2675        3         0    212.500000
# 2676       11         3    213.320007
#
# [2677 rows x 23 columns]

# %%
numeric_data = Data.select_dtypes(include=[np.number])


fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
mask = np.triu(np.ones_like(numeric_data.corr(), dtype=bool))
sns.heatmap(np.abs(numeric_data.corr()), mask=mask, annot=True, cmap='vlag_r', ax=ax)
plt.title('The correlation between features')
# Out:
# Text(0.5, 1.0, 'The correlation between features')

# %% [markdown]
# ## scaling and creating data sequence

# %%
#Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())
trg_min = Data['target_close'].min()
trg_max = Data['target_close'].max()
trg_min,trg_max
# Out:
# (np.float64(35.54750061035156), np.float64(259.0199890136719))

# %%
#Scaling each column separately
for c in Data.columns[1:]:
    Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())

# %%
WINDOW_SIZE = 10
data_x, data_y = [], []


for i in range(WINDOW_SIZE,len(Data)):
    data_x.append(Data.iloc[i-WINDOW_SIZE:i, 1:-1])
    data_y.append((Data.iloc[i, -1]))

# %%
data_x, data_y = np.array(data_x), np.array(data_y)

# %% [markdown]
# ## spliting data

# %%
data_x.shape[0]
# Out:
# 2667

# %%
limiter = 8 * (data_x.shape[0] // 10)

trainV_data_x = data_x[:limiter, :, :]
trainV_data_y = data_y[:limiter]

test_data_x = data_x[limiter:, :, :]
test_data_y = data_y[limiter:]

# %%
limiterValid = 8 * (trainV_data_x.shape[0] // 10)

valid_data_x = trainV_data_x[limiterValid:, :, :]
valid_data_y = trainV_data_y[limiterValid:]

train_data_x = trainV_data_x[:limiterValid, :, :]
train_data_y = trainV_data_y[:limiterValid]

# %%
valid_data_x.shape,valid_data_y.shape
# Out:
# ((432, 10, 21), (432,))

# %%
valid_data_y[:10]
# Out:
# array([0.53815348, 0.53815348, 0.53242571, 0.53882474, 0.53211251,
#        0.54513419, 0.54513419, 0.54513419, 0.57225161, 0.52933807])

# %%
train_data_x.shape,train_data_y.shape
# Out:
# ((1696, 10, 21), (1696,))

# %%
train_data_y[:10]
# Out:
# array([0.03904283, 0.03904283, 0.03904283, 0.03904283, 0.038036  ,
#        0.04129144, 0.04147042, 0.04057547, 0.04057547, 0.04057547])

# %%
test_data_x.shape,test_data_y.shape
# Out:
# ((539, 10, 21), (539,))

# %%
test_data_y[:10]
# Out:
# array([0.67503832, 0.67503832, 0.67503832, 0.66787864, 0.67969218,
#        0.68224279, 0.68985004, 0.68976053, 0.68976053, 0.68976053])

# %% [markdown]
# # Training

# %%
kernel_initializer=initializers.RandomNormal(stddev=0.01)
initializer = tf.keras.initializers.RandomUniform(minval=0., maxval=1.)

model = Sequential()


model.add(GRU(units=60, activation='relu',
               input_shape=(int(train_data_x.shape[1]),int(train_data_x.shape[2])),
               return_sequences=True))


model.add(GRU(units=35 ,return_sequences=False))
model.add(Dense(1))
model.add(Activation('relu'))


model.summary()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_4 (GRU)                     │ (None, 10, 60)         │        14,940 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 35)             │        10,185 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,161 (98.29 KB)
#  Trainable params: 25,161 (98.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def r2(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[r2])

# %%
history = model.fit(train_data_x, train_data_y, epochs=100, batch_size=48, validation_data=(valid_data_x, valid_data_y), verbose=1, callbacks=[
    ReduceLROnPlateau(monitor="val_r2", patience=15, factor=.1),
    EarlyStopping(monitor="val_loss", min_delta=1e-2, patience=45)
])
# Out:
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0150 - r2: -87.6479 - val_loss: 9.1564e-04 - val_r2: -180.8927 - learning_rate: 0.0010
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8967e-04 - r2: -93.8970 - val_loss: 6.6200e-04 - val_r2: -140.9384 - learning_rate: 0.0010
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3657e-04 - r2: -94.1182 - val_loss: 4.8692e-04 - val_r2: -121.2012 - learning_rate: 0.0010
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5255e-04 - r2: -94.5850 - val_loss: 5.2908e-04 - val_r2: -127.5621 - learning_rate: 0.0010
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4218e-04 - r2: -94.3575 - val_loss: 3.4188e-04 - val_r2: -104.1560 - learning_rate: 0.0010
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9886e-04 - r2: -94.9557 - val_loss: 3.5300e-04 - val_r2: -105.7239 - learning_rate: 0.0010
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7638e-04 - r2: -94.6264 - val_loss: 3.0612e-04 - val_r2: -100.2352 - learning_rate: 0.0010
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8792e-04 - r2: -94.9667 - val_loss: 2.9301e-04 - val_r2: -99.9858 - learning_rate: 0.0010
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7031e-04 - r2: -94.7816 - val_loss: 3.0899e-04 - val_r2: -101.9132 - learning_rate: 0.0010
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8467e-04 - r2: -95.2399 - val_loss: 3.7645e-04 - val_r2: -110.2962 - learning_rate: 0.0010
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5523e-04 - r2: -94.5593 - val_loss: 2.7323e-04 - val_r2: -97.5246 - learning_rate: 0.0010
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7157e-04 - r2: -95.0472 - val_loss: 2.8758e-04 - val_r2: -100.6083 - learning_rate: 0.0010
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6479e-04 - r2: -94.8306 - val_loss: 3.0642e-04 - val_r2: -101.9286 - learning_rate: 0.0010
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4764e-04 - r2: -94.4157 - val_loss: 2.8087e-04 - val_r2: -99.4491 - learning_rate: 0.0010
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5264e-04 - r2: -94.7198 - val_loss: 3.2270e-04 - val_r2: -104.4760 - learning_rate: 0.0010
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3942e-04 - r2: -94.6995 - val_loss: 2.5040e-04 - val_r2: -95.1515 - learning_rate: 0.0010
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1800e-04 - r2: -94.7592 - val_loss: 2.8222e-04 - val_r2: -99.7547 - learning_rate: 1.0000e-04
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2823e-04 - r2: -94.7627 - val_loss: 2.5823e-04 - val_r2: -96.7087 - learning_rate: 1.0000e-04
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0951e-04 - r2: -94.7793 - val_loss: 2.5998e-04 - val_r2: -96.8870 - learning_rate: 1.0000e-04
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1948e-04 - r2: -94.8559 - val_loss: 2.8837e-04 - val_r2: -100.7879 - learning_rate: 1.0000e-04
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1128e-04 - r2: -94.6388 - val_loss: 2.5356e-04 - val_r2: -96.1708 - learning_rate: 1.0000e-04
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2377e-04 - r2: -95.0107 - val_loss: 2.4734e-04 - val_r2: -95.4545 - learning_rate: 1.0000e-04
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1764e-04 - r2: -95.0469 - val_loss: 2.6031e-04 - val_r2: -97.2490 - learning_rate: 1.0000e-04
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3462e-04 - r2: -94.7258 - val_loss: 2.3965e-04 - val_r2: -94.4236 - learning_rate: 1.0000e-04
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2513e-04 - r2: -95.0266 - val_loss: 2.5440e-04 - val_r2: -96.2937 - learning_rate: 1.0000e-04
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2339e-04 - r2: -94.9059 - val_loss: 2.5232e-04 - val_r2: -96.2925 - learning_rate: 1.0000e-04
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1589e-04 - r2: -94.5671 - val_loss: 2.8915e-04 - val_r2: -101.0676 - learning_rate: 1.0000e-04
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2174e-04 - r2: -94.6935 - val_loss: 2.4301e-04 - val_r2: -95.0602 - learning_rate: 1.0000e-04
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2580e-04 - r2: -94.8611 - val_loss: 2.8895e-04 - val_r2: -101.1186 - learning_rate: 1.0000e-04
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2378e-04 - r2: -94.8560 - val_loss: 2.3753e-04 - val_r2: -94.3732 - learning_rate: 1.0000e-04
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1467e-04 - r2: -94.9921 - val_loss: 2.5568e-04 - val_r2: -96.7359 - learning_rate: 1.0000e-04
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2124e-04 - r2: -94.8125 - val_loss: 2.4645e-04 - val_r2: -95.5574 - learning_rate: 1.0000e-05
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1948e-04 - r2: -94.8533 - val_loss: 2.4901e-04 - val_r2: -95.9456 - learning_rate: 1.0000e-05
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1568e-04 - r2: -94.8231 - val_loss: 2.4850e-04 - val_r2: -95.8645 - learning_rate: 1.0000e-05
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2241e-04 - r2: -94.7371 - val_loss: 2.5558e-04 - val_r2: -96.7846 - learning_rate: 1.0000e-05
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1458e-04 - r2: -94.6245 - val_loss: 2.5468e-04 - val_r2: -96.6839 - learning_rate: 1.0000e-05
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1679e-04 - r2: -94.6868 - val_loss: 2.5501e-04 - val_r2: -96.6952 - learning_rate: 1.0000e-05
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2332e-04 - r2: -94.7441 - val_loss: 2.5135e-04 - val_r2: -96.2176 - learning_rate: 1.0000e-05
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1067e-04 - r2: -94.7662 - val_loss: 2.5576e-04 - val_r2: -96.8107 - learning_rate: 1.0000e-05
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1622e-04 - r2: -94.5991 - val_loss: 2.5387e-04 - val_r2: -96.5498 - learning_rate: 1.0000e-05
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1380e-04 - r2: -94.8041 - val_loss: 2.5324e-04 - val_r2: -96.4709 - learning_rate: 1.0000e-05
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0800e-04 - r2: -94.8314 - val_loss: 2.4869e-04 - val_r2: -95.8864 - learning_rate: 1.0000e-05
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2146e-04 - r2: -94.7933 - val_loss: 2.5250e-04 - val_r2: -96.3972 - learning_rate: 1.0000e-05
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1140e-04 - r2: -94.7830 - val_loss: 2.4941e-04 - val_r2: -95.9869 - learning_rate: 1.0000e-05
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0744e-04 - r2: -94.8565 - val_loss: 2.4851e-04 - val_r2: -95.8327 - learning_rate: 1.0000e-05
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1324e-04 - r2: -94.8908 - val_loss: 2.5200e-04 - val_r2: -96.3075 - learning_rate: 1.0000e-05

# %%
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='Validation_loss')
plt.legend()

# %%
plt.plot(history.history['r2'], label='training')
plt.plot(history.history['val_r2'], label='Validation')
plt.legend()

# %%
predictions = model.predict(test_data_x)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
Predictions = []
for i in range(len(predictions)):
    Predictions.append(predictions[i]*(trg_max-trg_min)+trg_min)

# %%
results = {'date' : stock_with_sentiment_data.date[limiter+WINDOW_SIZE:],
           'original': stock_with_sentiment_data.target_close[limiter+WINDOW_SIZE:],
          'predictions':Predictions
          }
df_results = pd.DataFrame(results) 
df_results.date = pd.to_datetime(df_results.date)
df_results.index = df_results.date

fig, ax = plt.subplots(figsize=(8,4))
ax.set_facecolor('#FFFFFF')
ax.plot(df_results['original'], color='dodgerblue', label='Original price')
plt.plot(df_results['predictions'], color='orangered', label='Predicted price')
plt.title('Test data vs prediction for close price all data')
plt.legend()

# %%
df_results = df_results[:-1]

# %%
r2 = r2_score(df_results['original'], df_results['predictions'])
mse = mean_squared_error(df_results['original'], df_results['predictions'])
mae = mean_absolute_error(df_results['original'], df_results['predictions'])
rmse = np.sqrt(mse)
print('R2 score is -> ', r2)
print('RMSE is -> ', rmse)
# Out:
# R2 score is ->  0.8711511579619285
# RMSE is ->  8.716740164494402

# %%
df_results
# Out:
#                  date    original           predictions
# date
# 2023-11-09 2023-11-09  186.399994  [179.82234279073418]
# 2023-11-10 2023-11-10  186.399994  [180.00354804744893]
# 2023-11-11 2023-11-11  186.399994  [181.61381596052615]
# 2023-11-12 2023-11-12  184.800003   [182.6545607067883]
# 2023-11-13 2023-11-13  187.440002  [183.47459308141242]
# ...               ...         ...                   ...
# 2025-04-25 2025-04-25  209.279999  [197.82936875679388]
# 2025-04-26 2025-04-26  209.279999  [199.59156457034805]
# 2025-04-27 2025-04-27  210.139999   [200.4955262541871]
# 2025-04-28 2025-04-28  211.210007  [201.46554180953808]
# 2025-04-29 2025-04-29  212.500000  [202.16869119918192]
#
# [538 rows x 3 columns]

# %%
df_results.dtypes
# Out:
# date           datetime64[ns]
# original              float64
# predictions            object
# dtype: object

# %%
df_results['predictions'] = df_results['predictions'].apply(lambda x: x[0])

# %%
df_results
# Out:
#                  date    original  predictions
# date
# 2023-11-09 2023-11-09  186.399994   179.822343
# 2023-11-10 2023-11-10  186.399994   180.003548
# 2023-11-11 2023-11-11  186.399994   181.613816
# 2023-11-12 2023-11-12  184.800003   182.654561
# 2023-11-13 2023-11-13  187.440002   183.474593
# ...               ...         ...          ...
# 2025-04-25 2025-04-25  209.279999   197.829369
# 2025-04-26 2025-04-26  209.279999   199.591565
# 2025-04-27 2025-04-27  210.139999   200.495526
# 2025-04-28 2025-04-28  211.210007   201.465542
# 2025-04-29 2025-04-29  212.500000   202.168691
#
# [538 rows x 3 columns]

# %%
df_results['original_prev'] = df_results['original'].shift(1)

# %%
df_results
# Out:
#                  date    original  predictions  original_prev
# date
# 2023-11-09 2023-11-09  186.399994   179.822343            NaN
# 2023-11-10 2023-11-10  186.399994   180.003548     186.399994
# 2023-11-11 2023-11-11  186.399994   181.613816     186.399994
# 2023-11-12 2023-11-12  184.800003   182.654561     186.399994
# 2023-11-13 2023-11-13  187.440002   183.474593     184.800003
# ...               ...         ...          ...            ...
# 2025-04-25 2025-04-25  209.279999   197.829369     209.279999
# 2025-04-26 2025-04-26  209.279999   199.591565     209.279999
# 2025-04-27 2025-04-27  210.139999   200.495526     209.279999
# 2025-04-28 2025-04-28  211.210007   201.465542     210.139999
# 2025-04-29 2025-04-29  212.500000   202.168691     211.210007
#
# [538 rows x 4 columns]

# %%
# Вычисляем дельты (направление движения)
df_results['true_diff'] = df_results['original'] - df_results['original_prev']
df_results['pred_diff'] = df_results['predictions'] - df_results['original_prev']

# %%
df_results
# Out:
#                  date    original  predictions  original_prev  true_diff  \
# date
# 2023-11-09 2023-11-09  186.399994   179.822343            NaN        NaN
# 2023-11-10 2023-11-10  186.399994   180.003548     186.399994   0.000000
# 2023-11-11 2023-11-11  186.399994   181.613816     186.399994   0.000000
# 2023-11-12 2023-11-12  184.800003   182.654561     186.399994  -1.599991
# 2023-11-13 2023-11-13  187.440002   183.474593     184.800003   2.639999
# ...               ...         ...          ...            ...        ...
# 2025-04-25 2025-04-25  209.279999   197.829369     209.279999   0.000000
# 2025-04-26 2025-04-26  209.279999   199.591565     209.279999   0.000000
# 2025-04-27 2025-04-27  210.139999   200.495526     209.279999   0.860001
# 2025-04-28 2025-04-28  211.210007   201.465542     210.139999   1.070007
# 2025-04-29 2025-04-29  212.500000   202.168691     211.210007   1.289993
#
#             pred_diff
# date
# 2023-11-09        NaN
# 2023-11-10  -6.396446
# 2023-11-11  -4.786178
# 2023-11-12  -3.745433
# 2023-11-13  -1.325410
# ...               ...
# 2025-04-25 -11.450630
# 2025-04-26  -9.688434
# 2025-04-27  -8.784473
# 2025-04-28  -8.674458
# 2025-04-29  -9.041316
#
# [538 rows x 6 columns]

# %%
df_results['correct_direction'] = np.sign(df_results['true_diff']) == np.sign(df_results['pred_diff'])
accuracy = df_results['correct_direction'].iloc[1:].mean()
print(f"Accuracy предсказанного направления движения цены: {accuracy:.2%}")
# Out:
# Accuracy предсказанного направления движения цены: 30.73%
