# %%
# pip install pandas scikit-learn matplotlib seaborn

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from keras.models import Sequential
from keras.layers import *
from keras.utils import *
from keras.optimizers import *
from keras.callbacks import *
from keras.metrics import *
from tensorflow.keras import initializers
from tensorflow.keras.layers import GRU

import pandas as pd
import numpy as np
from datetime import datetime

from collections import *
from sklearn.utils import *

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
### import the data
news_data = pd.read_csv("../../data/apple_news_aggregated.csv")
news_data.head()
# Out:
#          date  negative  neutral  positive
# 0  2018-01-01         0        2         0
# 1  2018-01-02         1        9         0
# 2  2018-01-03         3        4         0
# 3  2018-01-04         2        3         1
# 4  2018-01-05         3        2         0

# %%
### import the data
stock_data = pd.read_csv("../../data/stock_data_final_2018_2025.csv")
stock_data.head()
# Out:
#          date       open       high        low      close       volume  \
# 0  2018-01-01  42.630001  42.647499  42.305000  42.307499  103999600.0
# 1  2018-01-02  42.540001  43.075001  42.314999  43.064999  102223600.0
# 2  2018-01-03  43.132500  43.637501  42.990002  43.057499  118071600.0
# 3  2018-01-04  43.134998  43.367500  43.020000  43.257500   89738400.0
# 4  2018-01-05  43.360001  43.842499  43.262501  43.750000   94640000.0
#
#        sma_5     sma_20     ema_12     ema_26        rsi      macd  \
# 0  42.399999  43.199125  42.778539  42.940969  36.626383 -0.162430
# 1  42.458999  43.199000  42.822609  42.950156  51.991143 -0.127547
# 2  42.608999  43.199125  42.858746  42.958108  51.857092 -0.099361
# 3  42.798999  43.187374  42.920093  42.980285  55.176213 -0.060192
# 4  43.087499  43.200249  43.047771  43.037301  62.104664  0.010470
#
#    macd_signal  upper_Band  lower_Band    stoch_k    stoch_d       atr  \
# 0     0.006934   44.379324   42.018926   0.132489   2.182314  0.480331
# 1    -0.019962   44.379255   42.018744  14.992662   5.083465  0.500843
# 2    -0.035842   44.379319   42.018930  29.705782  14.943644  0.511319
# 3    -0.040712   44.360309   42.014440  50.140658  31.613034  0.499617
# 4    -0.030475   44.391804   42.008695  66.314014  48.720151  0.505716
#
#          adx
# 0  20.496033
# 1  19.296351
# 2  18.983802
# 3  18.693577
# 4  19.332961

# %%
stock_with_sentiment_data = pd.merge(stock_data, news_data, left_on='date', right_on='date', how='left')
stock_with_sentiment_data.head()
# Out:
#          date       open       high        low      close       volume  \
# 0  2018-01-01  42.630001  42.647499  42.305000  42.307499  103999600.0
# 1  2018-01-02  42.540001  43.075001  42.314999  43.064999  102223600.0
# 2  2018-01-03  43.132500  43.637501  42.990002  43.057499  118071600.0
# 3  2018-01-04  43.134998  43.367500  43.020000  43.257500   89738400.0
# 4  2018-01-05  43.360001  43.842499  43.262501  43.750000   94640000.0
#
#        sma_5     sma_20     ema_12     ema_26  ...  macd_signal  upper_Band  \
# 0  42.399999  43.199125  42.778539  42.940969  ...     0.006934   44.379324
# 1  42.458999  43.199000  42.822609  42.950156  ...    -0.019962   44.379255
# 2  42.608999  43.199125  42.858746  42.958108  ...    -0.035842   44.379319
# 3  42.798999  43.187374  42.920093  42.980285  ...    -0.040712   44.360309
# 4  43.087499  43.200249  43.047771  43.037301  ...    -0.030475   44.391804
#
#    lower_Band    stoch_k    stoch_d       atr        adx  negative  neutral  \
# 0   42.018926   0.132489   2.182314  0.480331  20.496033         0        2
# 1   42.018744  14.992662   5.083465  0.500843  19.296351         1        9
# 2   42.018930  29.705782  14.943644  0.511319  18.983802         3        4
# 3   42.014440  50.140658  31.613034  0.499617  18.693577         2        3
# 4   42.008695  66.314014  48.720151  0.505716  19.332961         3        2
#
#    positive
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#
# [5 rows x 22 columns]

# %%
stock_with_sentiment_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'sma_5', 'sma_20',
#        'ema_12', 'ema_26', 'rsi', 'macd', 'macd_signal', 'upper_Band',
#        'lower_Band', 'stoch_k', 'stoch_d', 'atr', 'adx', 'negative', 'neutral',
#        'positive'],
#       dtype='object')

# %%
stock_with_sentiment_data['target_close'] = stock_with_sentiment_data['close'].shift(-1)
stock_with_sentiment_data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
# 2677  2025-05-01  209.080002  214.559998  208.899994  213.320007   57365700.0
#
#            sma_5      sma_20      ema_12      ema_26  ...  upper_Band  \
# 0      42.399999   43.199125   42.778539   42.940969  ...   44.379324
# 1      42.458999   43.199000   42.822609   42.950156  ...   44.379255
# 2      42.608999   43.199125   42.858746   42.958108  ...   44.379319
# 3      42.798999   43.187374   42.920093   42.980285  ...   44.360309
# 4      43.087499   43.200249   43.047771   43.037301  ...   44.391804
# ...          ...         ...         ...         ...  ...         ...
# 2673  208.162000  198.834999  203.637482  203.551848  ...  215.043319
# 2674  209.269998  200.720999  204.637870  204.039859  ...  212.318059
# 2675  209.838000  201.338999  205.648968  204.570981  ...  213.759460
# 2676  210.482001  202.442999  206.702973  205.158316  ...  214.709264
# 2677  211.290002  203.201500  207.720978  205.762886  ...  216.168220
#
#       lower_Band    stoch_k    stoch_d       atr        adx  negative  \
# 0      42.018926   0.132489   2.182314  0.480331  20.496033         0
# 1      42.018744  14.992662   5.083465  0.500843  19.296351         1
# 2      42.018930  29.705782  14.943644  0.511319  18.983802         3
# 3      42.014440  50.140658  31.613034  0.499617  18.693577         2
# 4      42.008695  66.314014  48.720151  0.505716  19.332961         3
# ...          ...        ...        ...       ...        ...       ...
# 2673  182.626679  85.648072  83.804139  8.008324  21.354716         1
# 2674  189.123939  88.096709  86.333407  7.724872  20.815254         4
# 2675  188.918539  91.104717  88.283166  7.449524  20.435112         5
# 2676  190.176735  94.864740  91.355389  7.410987  19.700269         4
# 2677  190.234780  95.284777  93.751412  7.285917  19.197194        19
#
#       neutral  positive  target_close
# 0           2         0     43.064999
# 1           9         0     43.057499
# 2           4         0     43.257500
# 3           3         1     43.750000
# 4           2         0     43.750000
# ...       ...       ...           ...
# 2673        0         3    210.139999
# 2674        3         4    211.210007
# 2675        3         0    212.500000
# 2676       11         3    213.320007
# 2677       19         6           NaN
#
# [2678 rows x 23 columns]

# %%
stock_with_sentiment_data = stock_with_sentiment_data.drop([2677])
stock_with_sentiment_data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2672  2025-04-26  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
#
#            sma_5      sma_20      ema_12      ema_26  ...  upper_Band  \
# 0      42.399999   43.199125   42.778539   42.940969  ...   44.379324
# 1      42.458999   43.199000   42.822609   42.950156  ...   44.379255
# 2      42.608999   43.199125   42.858746   42.958108  ...   44.379319
# 3      42.798999   43.187374   42.920093   42.980285  ...   44.360309
# 4      43.087499   43.200249   43.047771   43.037301  ...   44.391804
# ...          ...         ...         ...         ...  ...         ...
# 2672  206.254001  197.443999  202.611570  203.093596  ...  214.576675
# 2673  208.162000  198.834999  203.637482  203.551848  ...  215.043319
# 2674  209.269998  200.720999  204.637870  204.039859  ...  212.318059
# 2675  209.838000  201.338999  205.648968  204.570981  ...  213.759460
# 2676  210.482001  202.442999  206.702973  205.158316  ...  214.709264
#
#       lower_Band    stoch_k    stoch_d       atr        adx  negative  \
# 0      42.018926   0.132489   2.182314  0.480331  20.496033         0
# 1      42.018744  14.992662   5.083465  0.500843  19.296351         1
# 2      42.018930  29.705782  14.943644  0.511319  18.983802         3
# 3      42.014440  50.140658  31.613034  0.499617  18.693577         2
# 4      42.008695  66.314014  48.720151  0.505716  19.332961         3
# ...          ...        ...        ...       ...        ...       ...
# 2672  180.311324  85.255441  80.031103  8.351271  22.240426         5
# 2673  182.626679  85.648072  83.804139  8.008324  21.354716         1
# 2674  189.123939  88.096709  86.333407  7.724872  20.815254         4
# 2675  188.918539  91.104717  88.283166  7.449524  20.435112         5
# 2676  190.176735  94.864740  91.355389  7.410987  19.700269         4
#
#       neutral  positive  target_close
# 0           2         0     43.064999
# 1           9         0     43.057499
# 2           4         0     43.257500
# 3           3         1     43.750000
# 4           2         0     43.750000
# ...       ...       ...           ...
# 2672       12         8    209.279999
# 2673        0         3    210.139999
# 2674        3         4    211.210007
# 2675        3         0    212.500000
# 2676       11         3    213.320007
#
# [2677 rows x 23 columns]

# %%
stock_with_sentiment_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'sma_5', 'sma_20',
#        'ema_12', 'ema_26', 'rsi', 'macd', 'macd_signal', 'upper_Band',
#        'lower_Band', 'stoch_k', 'stoch_d', 'atr', 'adx', 'negative', 'neutral',
#        'positive', 'target_close'],
#       dtype='object')

# %% [markdown]
# ## correlation

# %%
### select the features to work on
Data = stock_with_sentiment_data.copy()
Data = Data[['date',
             'open',
             'high',
             'low',
             'close',
             'volume',
             'sma_5', 'sma_20',
             'ema_12', 'ema_26', 
             'rsi', 
             'macd', 'macd_signal', 
             'upper_Band','lower_Band', 
             'stoch_k', 'stoch_d', 
             'atr', 'adx',
            #  'negative', 'neutral', 'positive',
             'target_close'
            ]]

Data = Data.sort_values(['date'])
Data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2672  2025-04-26  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
#
#            sma_5      sma_20      ema_12      ema_26        rsi      macd  \
# 0      42.399999   43.199125   42.778539   42.940969  36.626383 -0.162430
# 1      42.458999   43.199000   42.822609   42.950156  51.991143 -0.127547
# 2      42.608999   43.199125   42.858746   42.958108  51.857092 -0.099361
# 3      42.798999   43.187374   42.920093   42.980285  55.176213 -0.060192
# 4      43.087499   43.200249   43.047771   43.037301  62.104664  0.010470
# ...          ...         ...         ...         ...        ...       ...
# 2672  206.254001  197.443999  202.611570  203.093596  56.324729 -0.482026
# 2673  208.162000  198.834999  203.637482  203.551848  56.324729  0.085634
# 2674  209.269998  200.720999  204.637870  204.039859  57.163545  0.598010
# 2675  209.838000  201.338999  205.648968  204.570981  58.238235  1.077986
# 2676  210.482001  202.442999  206.702973  205.158316  59.555620  1.544657
#
#       macd_signal  upper_Band  lower_Band    stoch_k    stoch_d       atr  \
# 0        0.006934   44.379324   42.018926   0.132489   2.182314  0.480331
# 1       -0.019962   44.379255   42.018744  14.992662   5.083465  0.500843
# 2       -0.035842   44.379319   42.018930  29.705782  14.943644  0.511319
# 3       -0.040712   44.360309   42.014440  50.140658  31.613034  0.499617
# 4       -0.030475   44.391804   42.008695  66.314014  48.720151  0.505716
# ...           ...         ...         ...        ...        ...       ...
# 2672    -3.036244  214.576675  180.311324  85.255441  80.031103  8.351271
# 2673    -2.411869  215.043319  182.626679  85.648072  83.804139  8.008324
# 2674    -1.809893  212.318059  189.123939  88.096709  86.333407  7.724872
# 2675    -1.232317  213.759460  188.918539  91.104717  88.283166  7.449524
# 2676    -0.676922  214.709264  190.176735  94.864740  91.355389  7.410987
#
#             adx  target_close
# 0     20.496033     43.064999
# 1     19.296351     43.057499
# 2     18.983802     43.257500
# 3     18.693577     43.750000
# 4     19.332961     43.750000
# ...         ...           ...
# 2672  22.240426    209.279999
# 2673  21.354716    210.139999
# 2674  20.815254    211.210007
# 2675  20.435112    212.500000
# 2676  19.700269    213.320007
#
# [2677 rows x 20 columns]

# %%
numeric_data = Data.select_dtypes(include=[np.number])


fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
mask = np.triu(np.ones_like(numeric_data.corr(), dtype=bool))
sns.heatmap(np.abs(numeric_data.corr()), mask=mask, annot=True, cmap='vlag_r', ax=ax)
plt.title('The correlation between features')
# Out:
# Text(0.5, 1.0, 'The correlation between features')

# %% [markdown]
# ## scaling and creating data sequence

# %%
#Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())
trg_min = Data['target_close'].min()
trg_max = Data['target_close'].max()
trg_min,trg_max
# Out:
# (np.float64(35.54750061035156), np.float64(259.0199890136719))

# %%
#Scaling each column separately
for c in Data.columns[1:]:
    Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())

# %%
WINDOW_SIZE = 1
data_x, data_y = [], []


for i in range(WINDOW_SIZE,len(Data)):
    data_x.append(Data.iloc[i-WINDOW_SIZE:i, 1:-1])
    data_y.append((Data.iloc[i, -1]))

# %%
data_x, data_y = np.array(data_x), np.array(data_y)

# %% [markdown]
# ## spliting data

# %%
data_x.shape[0]
# Out:
# 2676

# %%
limiter = 8 * (data_x.shape[0] // 10)

trainV_data_x = data_x[:limiter, :, :]
trainV_data_y = data_y[:limiter]

test_data_x = data_x[limiter:, :, :]
test_data_y = data_y[limiter:]

# %%
limiterValid = 8 * (trainV_data_x.shape[0] // 10)

valid_data_x = trainV_data_x[limiterValid:, :, :]
valid_data_y = trainV_data_y[limiterValid:]

train_data_x = trainV_data_x[:limiterValid, :, :]
train_data_y = trainV_data_y[:limiterValid]

# %%
valid_data_x.shape,valid_data_y.shape
# Out:
# ((432, 1, 18), (432,))

# %%
valid_data_y[:10]
# Out:
# array([0.53815348, 0.53815348, 0.53815348, 0.53242571, 0.53882474,
#        0.53211251, 0.54513419, 0.54513419, 0.54513419, 0.57225161])

# %%
train_data_x.shape,train_data_y.shape
# Out:
# ((1704, 1, 18), (1704,))

# %%
train_data_y[:10]
# Out:
# array([0.03360592, 0.03450089, 0.03670474, 0.03670474, 0.03670474,
#        0.03597759, 0.03595521, 0.03591045, 0.03701798, 0.03904283])

# %%
test_data_x.shape,test_data_y.shape
# Out:
# ((540, 1, 18), (540,))

# %%
test_data_y[:10]
# Out:
# array([0.65718382, 0.67503832, 0.67503832, 0.67503832, 0.66787864,
#        0.67969218, 0.68224279, 0.68985004, 0.68976053, 0.68976053])

# %% [markdown]
# # Training

# %%
kernel_initializer=initializers.RandomNormal(stddev=0.01)
initializer = tf.keras.initializers.RandomUniform(minval=0., maxval=1.)

model = Sequential()


model.add(GRU(units=60, activation='relu',
               input_shape=(int(train_data_x.shape[1]),int(train_data_x.shape[2])),
               return_sequences=True))


model.add(GRU(units=35 ,return_sequences=False))
model.add(Dense(1))
model.add(Activation('relu'))


model.summary()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_12 (GRU)                    │ (None, 1, 60)          │        14,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_13 (GRU)                    │ (None, 35)             │        10,185 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,621 (96.18 KB)
#  Trainable params: 24,621 (96.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def r2(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[r2])

# %%
history = model.fit(train_data_x, train_data_y, epochs=100, batch_size=48, validation_data=(valid_data_x, valid_data_y), verbose=1, callbacks=[
    ReduceLROnPlateau(monitor="val_r2", patience=15, factor=.1),
    EarlyStopping(monitor="val_loss", min_delta=1e-2, patience=45)
])
# Out:
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0644 - r2: -91.7155 - val_loss: 0.0069 - val_r2: -1029.5236 - learning_rate: 0.0010
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0024 - r2: -88.1348 - val_loss: 6.0559e-04 - val_r2: -131.9675 - learning_rate: 0.0010
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5305e-04 - r2: -93.4453 - val_loss: 3.4243e-04 - val_r2: -117.6968 - learning_rate: 0.0010
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7927e-04 - r2: -94.8543 - val_loss: 2.7773e-04 - val_r2: -107.7386 - learning_rate: 0.0010
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3627e-04 - r2: -94.5715 - val_loss: 2.4934e-04 - val_r2: -102.6914 - learning_rate: 0.0010
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5436e-04 - r2: -94.6233 - val_loss: 2.4391e-04 - val_r2: -102.0384 - learning_rate: 0.0010
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4534e-04 - r2: -94.6505 - val_loss: 2.5203e-04 - val_r2: -102.4699 - learning_rate: 0.0010
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5267e-04 - r2: -94.7599 - val_loss: 2.3837e-04 - val_r2: -100.4214 - learning_rate: 0.0010
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4442e-04 - r2: -94.7711 - val_loss: 2.3708e-04 - val_r2: -100.4770 - learning_rate: 0.0010
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4578e-04 - r2: -94.6703 - val_loss: 2.3362e-04 - val_r2: -99.5732 - learning_rate: 0.0010
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3152e-04 - r2: -94.7721 - val_loss: 2.3476e-04 - val_r2: -100.2159 - learning_rate: 0.0010
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4104e-04 - r2: -94.8630 - val_loss: 2.4296e-04 - val_r2: -101.3214 - learning_rate: 0.0010
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3650e-04 - r2: -94.9145 - val_loss: 2.4184e-04 - val_r2: -100.3201 - learning_rate: 0.0010
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2008e-04 - r2: -94.8306 - val_loss: 2.2988e-04 - val_r2: -99.3862 - learning_rate: 0.0010
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3532e-04 - r2: -94.8424 - val_loss: 2.3404e-04 - val_r2: -99.6625 - learning_rate: 0.0010
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2564e-04 - r2: -94.6478 - val_loss: 2.7792e-04 - val_r2: -104.3791 - learning_rate: 0.0010
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3412e-04 - r2: -94.2966 - val_loss: 2.3043e-04 - val_r2: -98.7930 - learning_rate: 1.0000e-04
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1931e-04 - r2: -94.6683 - val_loss: 2.2754e-04 - val_r2: -98.4713 - learning_rate: 1.0000e-04
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2274e-04 - r2: -94.7774 - val_loss: 2.2622e-04 - val_r2: -98.4235 - learning_rate: 1.0000e-04
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1546e-04 - r2: -94.7100 - val_loss: 2.2503e-04 - val_r2: -98.4009 - learning_rate: 1.0000e-04
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2455e-04 - r2: -94.7115 - val_loss: 2.2543e-04 - val_r2: -98.2134 - learning_rate: 1.0000e-04
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2006e-04 - r2: -94.7182 - val_loss: 2.2678e-04 - val_r2: -98.3286 - learning_rate: 1.0000e-04
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1652e-04 - r2: -94.5999 - val_loss: 2.2962e-04 - val_r2: -98.5908 - learning_rate: 1.0000e-04
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1487e-04 - r2: -94.6895 - val_loss: 2.2508e-04 - val_r2: -98.3509 - learning_rate: 1.0000e-04
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1203e-04 - r2: -94.9626 - val_loss: 2.2563e-04 - val_r2: -98.1630 - learning_rate: 1.0000e-04
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1457e-04 - r2: -94.7689 - val_loss: 2.2501e-04 - val_r2: -98.2626 - learning_rate: 1.0000e-04
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1379e-04 - r2: -94.8314 - val_loss: 2.2898e-04 - val_r2: -98.4904 - learning_rate: 1.0000e-04
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0511e-04 - r2: -94.8106 - val_loss: 2.2853e-04 - val_r2: -98.4918 - learning_rate: 1.0000e-04
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1869e-04 - r2: -94.6555 - val_loss: 2.2661e-04 - val_r2: -98.2175 - learning_rate: 1.0000e-04
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0613e-04 - r2: -94.6398 - val_loss: 2.2447e-04 - val_r2: -98.0989 - learning_rate: 1.0000e-04
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2698e-04 - r2: -94.8468 - val_loss: 2.2432e-04 - val_r2: -98.2572 - learning_rate: 1.0000e-04
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2024e-04 - r2: -94.6796 - val_loss: 2.2576e-04 - val_r2: -98.3034 - learning_rate: 1.0000e-05
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1668e-04 - r2: -94.5599 - val_loss: 2.2659e-04 - val_r2: -98.3654 - learning_rate: 1.0000e-05
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1950e-04 - r2: -94.6450 - val_loss: 2.2559e-04 - val_r2: -98.2604 - learning_rate: 1.0000e-05
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1384e-04 - r2: -94.8688 - val_loss: 2.2594e-04 - val_r2: -98.2865 - learning_rate: 1.0000e-05
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1503e-04 - r2: -95.1338 - val_loss: 2.2545e-04 - val_r2: -98.2375 - learning_rate: 1.0000e-05
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0942e-04 - r2: -94.8999 - val_loss: 2.2585e-04 - val_r2: -98.2791 - learning_rate: 1.0000e-05
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1804e-04 - r2: -94.8396 - val_loss: 2.2518e-04 - val_r2: -98.2266 - learning_rate: 1.0000e-05
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2029e-04 - r2: -94.8983 - val_loss: 2.2500e-04 - val_r2: -98.1813 - learning_rate: 1.0000e-05
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1433e-04 - r2: -94.7890 - val_loss: 2.2513e-04 - val_r2: -98.2017 - learning_rate: 1.0000e-05
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2206e-04 - r2: -94.5477 - val_loss: 2.2628e-04 - val_r2: -98.2787 - learning_rate: 1.0000e-05
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2654e-04 - r2: -94.6170 - val_loss: 2.2686e-04 - val_r2: -98.3392 - learning_rate: 1.0000e-05
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1730e-04 - r2: -94.7524 - val_loss: 2.2580e-04 - val_r2: -98.2405 - learning_rate: 1.0000e-05
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2057e-04 - r2: -94.7842 - val_loss: 2.2492e-04 - val_r2: -98.1483 - learning_rate: 1.0000e-05
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1966e-04 - r2: -94.7676 - val_loss: 2.2627e-04 - val_r2: -98.2827 - learning_rate: 1.0000e-05
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1266e-04 - r2: -94.8231 - val_loss: 2.2547e-04 - val_r2: -98.1769 - learning_rate: 1.0000e-05

# %%
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='Validation_loss')
plt.legend()

# %%
plt.plot(history.history['r2'], label='training')
plt.plot(history.history['val_r2'], label='Validation')
plt.legend()

# %%
predictions = model.predict(test_data_x)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
Predictions = []
for i in range(len(predictions)):
    Predictions.append(predictions[i]*(trg_max-trg_min)+trg_min)

# %%
results = {'date' : stock_with_sentiment_data.date[limiter+WINDOW_SIZE:],
           'original': stock_with_sentiment_data.target_close[limiter+WINDOW_SIZE:],
          'predictions':Predictions
          }
df_results = pd.DataFrame(results) 
df_results.date = pd.to_datetime(df_results.date)
df_results.index = df_results.date

fig, ax = plt.subplots(figsize=(8,4))
ax.set_facecolor('#FFFFFF')
ax.plot(df_results['original'], color='dodgerblue', label='Original price')
plt.plot(df_results['predictions'], color='orangered', label='Predicted price')
plt.title('Test data vs prediction for close price all data')
plt.legend()

# %%
df_results = df_results[:-1]

# %%
r2 = r2_score(df_results['original'], df_results['predictions'])
mse = mean_squared_error(df_results['original'], df_results['predictions'])
mae = mean_absolute_error(df_results['original'], df_results['predictions'])
rmse = np.sqrt(mse)
print('R2 score is -> ', r2)
print('RMSE is -> ', rmse)
# Out:
# R2 score is ->  0.9592052009238006
# RMSE is ->  4.90588873147686

# %%
df_results
# Out:
#                  date    original           predictions
# date
# 2023-11-08 2023-11-08  182.410004  [180.31849940697703]
# 2023-11-09 2023-11-09  186.399994    [181.750865422915]
# 2023-11-10 2023-11-10  186.399994  [181.69123179057806]
# 2023-11-11 2023-11-11  186.399994  [184.54955690327733]
# 2023-11-12 2023-11-12  184.800003    [185.004408204828]
# ...               ...         ...                   ...
# 2025-04-25 2025-04-25  209.279999  [205.83765808771204]
# 2025-04-26 2025-04-26  209.279999  [207.29593150032088]
# 2025-04-27 2025-04-27  210.139999  [207.83400615117716]
# 2025-04-28 2025-04-28  211.210007   [208.2961967717847]
# 2025-04-29 2025-04-29  212.500000  [210.06188242489043]
#
# [539 rows x 3 columns]

# %%
df_results.dtypes
# Out:
# date           datetime64[ns]
# original              float64
# predictions            object
# dtype: object

# %%
df_results['predictions'] = df_results['predictions'].apply(lambda x: x[0])

# %%
df_results
# Out:
#                  date    original  predictions
# date
# 2023-11-08 2023-11-08  182.410004   180.318499
# 2023-11-09 2023-11-09  186.399994   181.750865
# 2023-11-10 2023-11-10  186.399994   181.691232
# 2023-11-11 2023-11-11  186.399994   184.549557
# 2023-11-12 2023-11-12  184.800003   185.004408
# ...               ...         ...          ...
# 2025-04-25 2025-04-25  209.279999   205.837658
# 2025-04-26 2025-04-26  209.279999   207.295932
# 2025-04-27 2025-04-27  210.139999   207.834006
# 2025-04-28 2025-04-28  211.210007   208.296197
# 2025-04-29 2025-04-29  212.500000   210.061882
#
# [539 rows x 3 columns]

# %%
df_results['original_prev'] = df_results['original'].shift(1)

# %%
df_results
# Out:
#                  date    original  predictions  original_prev
# date
# 2023-11-08 2023-11-08  182.410004   180.318499            NaN
# 2023-11-09 2023-11-09  186.399994   181.750865     182.410004
# 2023-11-10 2023-11-10  186.399994   181.691232     186.399994
# 2023-11-11 2023-11-11  186.399994   184.549557     186.399994
# 2023-11-12 2023-11-12  184.800003   185.004408     186.399994
# ...               ...         ...          ...            ...
# 2025-04-25 2025-04-25  209.279999   205.837658     209.279999
# 2025-04-26 2025-04-26  209.279999   207.295932     209.279999
# 2025-04-27 2025-04-27  210.139999   207.834006     209.279999
# 2025-04-28 2025-04-28  211.210007   208.296197     210.139999
# 2025-04-29 2025-04-29  212.500000   210.061882     211.210007
#
# [539 rows x 4 columns]

# %%
# Вычисляем дельты (направление движения)
df_results['true_diff'] = df_results['original'] - df_results['original_prev']
df_results['pred_diff'] = df_results['predictions'] - df_results['original_prev']

# %%
df_results
# Out:
#                  date    original  predictions  original_prev  true_diff  \
# date
# 2023-11-08 2023-11-08  182.410004   180.318499            NaN        NaN
# 2023-11-09 2023-11-09  186.399994   181.750865     182.410004   3.989990
# 2023-11-10 2023-11-10  186.399994   181.691232     186.399994   0.000000
# 2023-11-11 2023-11-11  186.399994   184.549557     186.399994   0.000000
# 2023-11-12 2023-11-12  184.800003   185.004408     186.399994  -1.599991
# ...               ...         ...          ...            ...        ...
# 2025-04-25 2025-04-25  209.279999   205.837658     209.279999   0.000000
# 2025-04-26 2025-04-26  209.279999   207.295932     209.279999   0.000000
# 2025-04-27 2025-04-27  210.139999   207.834006     209.279999   0.860001
# 2025-04-28 2025-04-28  211.210007   208.296197     210.139999   1.070007
# 2025-04-29 2025-04-29  212.500000   210.061882     211.210007   1.289993
#
#             pred_diff
# date
# 2023-11-08        NaN
# 2023-11-09  -0.659138
# 2023-11-10  -4.708762
# 2023-11-11  -1.850437
# 2023-11-12  -1.395586
# ...               ...
# 2025-04-25  -3.442341
# 2025-04-26  -1.984067
# 2025-04-27  -1.445993
# 2025-04-28  -1.843803
# 2025-04-29  -1.148124
#
# [539 rows x 6 columns]

# %%
df_results['correct_direction'] = np.sign(df_results['true_diff']) == np.sign(df_results['pred_diff'])
accuracy = df_results['correct_direction'].iloc[1:].mean()
print(f"Accuracy предсказанного направления движения цены: {accuracy:.2%}")
# Out:
# Accuracy предсказанного направления движения цены: 34.76%
