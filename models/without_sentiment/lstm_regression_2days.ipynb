# %%
# pip install pandas scikit-learn matplotlib seaborn

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from keras.models import Sequential
from keras.layers import *
from keras.utils import *
from keras.optimizers import *
from keras.callbacks import *
from keras.metrics import *
from tensorflow.keras import initializers

import pandas as pd
import numpy as np
from datetime import datetime

from collections import *
from sklearn.utils import *

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
### import the data
news_data = pd.read_csv("../../data/apple_news_aggregated.csv")
news_data.head()
# Out:
#          date  negative  neutral  positive
# 0  2018-01-01         0        2         0
# 1  2018-01-02         1        9         0
# 2  2018-01-03         3        4         0
# 3  2018-01-04         2        3         1
# 4  2018-01-05         3        2         0

# %%
### import the data
stock_data = pd.read_csv("../../data/stock_data_final_2018_2025.csv")
stock_data.head()
# Out:
#          date       open       high        low      close       volume  \
# 0  2018-01-01  42.630001  42.647499  42.305000  42.307499  103999600.0
# 1  2018-01-02  42.540001  43.075001  42.314999  43.064999  102223600.0
# 2  2018-01-03  43.132500  43.637501  42.990002  43.057499  118071600.0
# 3  2018-01-04  43.134998  43.367500  43.020000  43.257500   89738400.0
# 4  2018-01-05  43.360001  43.842499  43.262501  43.750000   94640000.0
#
#        sma_5     sma_20     ema_12     ema_26        rsi      macd  \
# 0  42.399999  43.199125  42.778539  42.940969  36.626383 -0.162430
# 1  42.458999  43.199000  42.822609  42.950156  51.991143 -0.127547
# 2  42.608999  43.199125  42.858746  42.958108  51.857092 -0.099361
# 3  42.798999  43.187374  42.920093  42.980285  55.176213 -0.060192
# 4  43.087499  43.200249  43.047771  43.037301  62.104664  0.010470
#
#    macd_signal  upper_Band  lower_Band    stoch_k    stoch_d       atr  \
# 0     0.006934   44.379324   42.018926   0.132489   2.182314  0.480331
# 1    -0.019962   44.379255   42.018744  14.992662   5.083465  0.500843
# 2    -0.035842   44.379319   42.018930  29.705782  14.943644  0.511319
# 3    -0.040712   44.360309   42.014440  50.140658  31.613034  0.499617
# 4    -0.030475   44.391804   42.008695  66.314014  48.720151  0.505716
#
#          adx
# 0  20.496033
# 1  19.296351
# 2  18.983802
# 3  18.693577
# 4  19.332961

# %%
stock_with_sentiment_data = pd.merge(stock_data, news_data, left_on='date', right_on='date', how='left')
stock_with_sentiment_data.head()
# Out:
#          date       open       high        low      close       volume  \
# 0  2018-01-01  42.630001  42.647499  42.305000  42.307499  103999600.0
# 1  2018-01-02  42.540001  43.075001  42.314999  43.064999  102223600.0
# 2  2018-01-03  43.132500  43.637501  42.990002  43.057499  118071600.0
# 3  2018-01-04  43.134998  43.367500  43.020000  43.257500   89738400.0
# 4  2018-01-05  43.360001  43.842499  43.262501  43.750000   94640000.0
#
#        sma_5     sma_20     ema_12     ema_26  ...  macd_signal  upper_Band  \
# 0  42.399999  43.199125  42.778539  42.940969  ...     0.006934   44.379324
# 1  42.458999  43.199000  42.822609  42.950156  ...    -0.019962   44.379255
# 2  42.608999  43.199125  42.858746  42.958108  ...    -0.035842   44.379319
# 3  42.798999  43.187374  42.920093  42.980285  ...    -0.040712   44.360309
# 4  43.087499  43.200249  43.047771  43.037301  ...    -0.030475   44.391804
#
#    lower_Band    stoch_k    stoch_d       atr        adx  negative  neutral  \
# 0   42.018926   0.132489   2.182314  0.480331  20.496033         0        2
# 1   42.018744  14.992662   5.083465  0.500843  19.296351         1        9
# 2   42.018930  29.705782  14.943644  0.511319  18.983802         3        4
# 3   42.014440  50.140658  31.613034  0.499617  18.693577         2        3
# 4   42.008695  66.314014  48.720151  0.505716  19.332961         3        2
#
#    positive
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#
# [5 rows x 22 columns]

# %%
stock_with_sentiment_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'sma_5', 'sma_20',
#        'ema_12', 'ema_26', 'rsi', 'macd', 'macd_signal', 'upper_Band',
#        'lower_Band', 'stoch_k', 'stoch_d', 'atr', 'adx', 'negative', 'neutral',
#        'positive'],
#       dtype='object')

# %%
stock_with_sentiment_data['target_close'] = stock_with_sentiment_data['close'].shift(-1)
stock_with_sentiment_data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
# 2677  2025-05-01  209.080002  214.559998  208.899994  213.320007   57365700.0
#
#            sma_5      sma_20      ema_12      ema_26  ...  upper_Band  \
# 0      42.399999   43.199125   42.778539   42.940969  ...   44.379324
# 1      42.458999   43.199000   42.822609   42.950156  ...   44.379255
# 2      42.608999   43.199125   42.858746   42.958108  ...   44.379319
# 3      42.798999   43.187374   42.920093   42.980285  ...   44.360309
# 4      43.087499   43.200249   43.047771   43.037301  ...   44.391804
# ...          ...         ...         ...         ...  ...         ...
# 2673  208.162000  198.834999  203.637482  203.551848  ...  215.043319
# 2674  209.269998  200.720999  204.637870  204.039859  ...  212.318059
# 2675  209.838000  201.338999  205.648968  204.570981  ...  213.759460
# 2676  210.482001  202.442999  206.702973  205.158316  ...  214.709264
# 2677  211.290002  203.201500  207.720978  205.762886  ...  216.168220
#
#       lower_Band    stoch_k    stoch_d       atr        adx  negative  \
# 0      42.018926   0.132489   2.182314  0.480331  20.496033         0
# 1      42.018744  14.992662   5.083465  0.500843  19.296351         1
# 2      42.018930  29.705782  14.943644  0.511319  18.983802         3
# 3      42.014440  50.140658  31.613034  0.499617  18.693577         2
# 4      42.008695  66.314014  48.720151  0.505716  19.332961         3
# ...          ...        ...        ...       ...        ...       ...
# 2673  182.626679  85.648072  83.804139  8.008324  21.354716         1
# 2674  189.123939  88.096709  86.333407  7.724872  20.815254         4
# 2675  188.918539  91.104717  88.283166  7.449524  20.435112         5
# 2676  190.176735  94.864740  91.355389  7.410987  19.700269         4
# 2677  190.234780  95.284777  93.751412  7.285917  19.197194        19
#
#       neutral  positive  target_close
# 0           2         0     43.064999
# 1           9         0     43.057499
# 2           4         0     43.257500
# 3           3         1     43.750000
# 4           2         0     43.750000
# ...       ...       ...           ...
# 2673        0         3    210.139999
# 2674        3         4    211.210007
# 2675        3         0    212.500000
# 2676       11         3    213.320007
# 2677       19         6           NaN
#
# [2678 rows x 23 columns]

# %%
stock_with_sentiment_data = stock_with_sentiment_data.drop([2677])
stock_with_sentiment_data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2672  2025-04-26  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
#
#            sma_5      sma_20      ema_12      ema_26  ...  upper_Band  \
# 0      42.399999   43.199125   42.778539   42.940969  ...   44.379324
# 1      42.458999   43.199000   42.822609   42.950156  ...   44.379255
# 2      42.608999   43.199125   42.858746   42.958108  ...   44.379319
# 3      42.798999   43.187374   42.920093   42.980285  ...   44.360309
# 4      43.087499   43.200249   43.047771   43.037301  ...   44.391804
# ...          ...         ...         ...         ...  ...         ...
# 2672  206.254001  197.443999  202.611570  203.093596  ...  214.576675
# 2673  208.162000  198.834999  203.637482  203.551848  ...  215.043319
# 2674  209.269998  200.720999  204.637870  204.039859  ...  212.318059
# 2675  209.838000  201.338999  205.648968  204.570981  ...  213.759460
# 2676  210.482001  202.442999  206.702973  205.158316  ...  214.709264
#
#       lower_Band    stoch_k    stoch_d       atr        adx  negative  \
# 0      42.018926   0.132489   2.182314  0.480331  20.496033         0
# 1      42.018744  14.992662   5.083465  0.500843  19.296351         1
# 2      42.018930  29.705782  14.943644  0.511319  18.983802         3
# 3      42.014440  50.140658  31.613034  0.499617  18.693577         2
# 4      42.008695  66.314014  48.720151  0.505716  19.332961         3
# ...          ...        ...        ...       ...        ...       ...
# 2672  180.311324  85.255441  80.031103  8.351271  22.240426         5
# 2673  182.626679  85.648072  83.804139  8.008324  21.354716         1
# 2674  189.123939  88.096709  86.333407  7.724872  20.815254         4
# 2675  188.918539  91.104717  88.283166  7.449524  20.435112         5
# 2676  190.176735  94.864740  91.355389  7.410987  19.700269         4
#
#       neutral  positive  target_close
# 0           2         0     43.064999
# 1           9         0     43.057499
# 2           4         0     43.257500
# 3           3         1     43.750000
# 4           2         0     43.750000
# ...       ...       ...           ...
# 2672       12         8    209.279999
# 2673        0         3    210.139999
# 2674        3         4    211.210007
# 2675        3         0    212.500000
# 2676       11         3    213.320007
#
# [2677 rows x 23 columns]

# %%
stock_with_sentiment_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'sma_5', 'sma_20',
#        'ema_12', 'ema_26', 'rsi', 'macd', 'macd_signal', 'upper_Band',
#        'lower_Band', 'stoch_k', 'stoch_d', 'atr', 'adx', 'negative', 'neutral',
#        'positive', 'target_close'],
#       dtype='object')

# %% [markdown]
# ## correlation

# %%
### select the features to work on
Data = stock_with_sentiment_data.copy()
Data = Data[['date',
             'open',
             'high',
             'low',
             'close',
             'volume',
             'sma_5', 'sma_20',
             'ema_12', 'ema_26', 
             'rsi', 
             'macd', 'macd_signal', 
             'upper_Band','lower_Band', 
             'stoch_k', 'stoch_d', 
             'atr', 'adx',
            #  'negative', 'neutral', 'positive',
             'target_close'
            ]]

Data = Data.sort_values(['date'])
Data
# Out:
#             date        open        high         low       close       volume  \
# 0     2018-01-01   42.630001   42.647499   42.305000   42.307499  103999600.0
# 1     2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
# 2     2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600.0
# 3     2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400.0
# 4     2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000.0
# ...          ...         ...         ...         ...         ...          ...
# 2672  2025-04-26  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2673  2025-04-27  206.369995  209.750000  206.199997  209.279999   38222300.0
# 2674  2025-04-28  210.000000  211.500000  207.460007  210.139999   38743100.0
# 2675  2025-04-29  208.690002  212.240005  208.369995  211.210007   36827600.0
# 2676  2025-04-30  209.300003  213.580002  206.669998  212.500000   52286500.0
#
#            sma_5      sma_20      ema_12      ema_26        rsi      macd  \
# 0      42.399999   43.199125   42.778539   42.940969  36.626383 -0.162430
# 1      42.458999   43.199000   42.822609   42.950156  51.991143 -0.127547
# 2      42.608999   43.199125   42.858746   42.958108  51.857092 -0.099361
# 3      42.798999   43.187374   42.920093   42.980285  55.176213 -0.060192
# 4      43.087499   43.200249   43.047771   43.037301  62.104664  0.010470
# ...          ...         ...         ...         ...        ...       ...
# 2672  206.254001  197.443999  202.611570  203.093596  56.324729 -0.482026
# 2673  208.162000  198.834999  203.637482  203.551848  56.324729  0.085634
# 2674  209.269998  200.720999  204.637870  204.039859  57.163545  0.598010
# 2675  209.838000  201.338999  205.648968  204.570981  58.238235  1.077986
# 2676  210.482001  202.442999  206.702973  205.158316  59.555620  1.544657
#
#       macd_signal  upper_Band  lower_Band    stoch_k    stoch_d       atr  \
# 0        0.006934   44.379324   42.018926   0.132489   2.182314  0.480331
# 1       -0.019962   44.379255   42.018744  14.992662   5.083465  0.500843
# 2       -0.035842   44.379319   42.018930  29.705782  14.943644  0.511319
# 3       -0.040712   44.360309   42.014440  50.140658  31.613034  0.499617
# 4       -0.030475   44.391804   42.008695  66.314014  48.720151  0.505716
# ...           ...         ...         ...        ...        ...       ...
# 2672    -3.036244  214.576675  180.311324  85.255441  80.031103  8.351271
# 2673    -2.411869  215.043319  182.626679  85.648072  83.804139  8.008324
# 2674    -1.809893  212.318059  189.123939  88.096709  86.333407  7.724872
# 2675    -1.232317  213.759460  188.918539  91.104717  88.283166  7.449524
# 2676    -0.676922  214.709264  190.176735  94.864740  91.355389  7.410987
#
#             adx  target_close
# 0     20.496033     43.064999
# 1     19.296351     43.057499
# 2     18.983802     43.257500
# 3     18.693577     43.750000
# 4     19.332961     43.750000
# ...         ...           ...
# 2672  22.240426    209.279999
# 2673  21.354716    210.139999
# 2674  20.815254    211.210007
# 2675  20.435112    212.500000
# 2676  19.700269    213.320007
#
# [2677 rows x 20 columns]

# %%
numeric_data = Data.select_dtypes(include=[np.number])


fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
mask = np.triu(np.ones_like(numeric_data.corr(), dtype=bool))
sns.heatmap(np.abs(numeric_data.corr()), mask=mask, annot=True, cmap='vlag_r', ax=ax)
plt.title('The correlation between features')
# Out:
# Text(0.5, 1.0, 'The correlation between features')

# %% [markdown]
# ## scaling and creating data sequence

# %%
#Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())
trg_min = Data['target_close'].min()
trg_max = Data['target_close'].max()
trg_min,trg_max
# Out:
# (np.float64(35.54750061035156), np.float64(259.0199890136719))

# %%
#Scaling each column separately
for c in Data.columns[1:]:
    Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())

# %%
WINDOW_SIZE = 2
data_x, data_y = [], []


for i in range(WINDOW_SIZE,len(Data)):
    data_x.append(Data.iloc[i-WINDOW_SIZE:i, 1:-1])
    data_y.append((Data.iloc[i, -1]))

# %%
data_x, data_y = np.array(data_x), np.array(data_y)

# %% [markdown]
# ## spliting data

# %%
data_x.shape[0]
# Out:
# 2675

# %%
limiter = 8 * (data_x.shape[0] // 10)

trainV_data_x = data_x[:limiter, :, :]
trainV_data_y = data_y[:limiter]

test_data_x = data_x[limiter:, :, :]
test_data_y = data_y[limiter:]

# %%
limiterValid = 8 * (trainV_data_x.shape[0] // 10)

valid_data_x = trainV_data_x[limiterValid:, :, :]
valid_data_y = trainV_data_y[limiterValid:]

train_data_x = trainV_data_x[:limiterValid, :, :]
train_data_y = trainV_data_y[:limiterValid]

# %%
valid_data_x.shape,valid_data_y.shape
# Out:
# ((432, 2, 18), (432,))

# %%
valid_data_y[:10]
# Out:
# array([0.53815348, 0.53815348, 0.53242571, 0.53882474, 0.53211251,
#        0.54513419, 0.54513419, 0.54513419, 0.57225161, 0.52933807])

# %%
train_data_x.shape,train_data_y.shape
# Out:
# ((1704, 2, 18), (1704,))

# %%
train_data_y[:10]
# Out:
# array([0.03450089, 0.03670474, 0.03670474, 0.03670474, 0.03597759,
#        0.03595521, 0.03591045, 0.03701798, 0.03904283, 0.03904283])

# %%
test_data_x.shape,test_data_y.shape
# Out:
# ((539, 2, 18), (539,))

# %%
test_data_y[:10]
# Out:
# array([0.67503832, 0.67503832, 0.67503832, 0.66787864, 0.67969218,
#        0.68224279, 0.68985004, 0.68976053, 0.68976053, 0.68976053])

# %% [markdown]
# # Training

# %%
kernel_initializer=initializers.RandomNormal(stddev=0.01)
initializer = tf.keras.initializers.RandomUniform(minval=0., maxval=1.)

model = Sequential()


model.add(LSTM(units=60, activation='relu',
               input_shape=(int(train_data_x.shape[1]),int(train_data_x.shape[2])),
               return_sequences=True))


model.add(LSTM(units=35 ,return_sequences=False))
model.add(Dense(1))
model.add(Activation('relu'))


model.summary()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 2, 60)          │        18,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 35)             │        13,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,436 (126.70 KB)
#  Trainable params: 32,436 (126.70 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def r2(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[r2])

# %%
history = model.fit(train_data_x, train_data_y, epochs=100, batch_size=48, validation_data=(valid_data_x, valid_data_y), verbose=1, callbacks=[
    ReduceLROnPlateau(monitor="val_r2", patience=15, factor=.1),
    EarlyStopping(monitor="val_loss", min_delta=1e-2, patience=45)
])
# Out:
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0640 - r2: -89.7091 - val_loss: 0.0096 - val_r2: -1317.5042 - learning_rate: 0.0010
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - r2: -81.2078 - val_loss: 4.6405e-04 - val_r2: -138.8699 - learning_rate: 0.0010
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0721e-04 - r2: -92.2745 - val_loss: 5.0608e-04 - val_r2: -147.4431 - learning_rate: 0.0010
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9819e-04 - r2: -94.7572 - val_loss: 4.7315e-04 - val_r2: -141.0106 - learning_rate: 0.0010
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2141e-04 - r2: -94.7469 - val_loss: 4.1674e-04 - val_r2: -129.7672 - learning_rate: 0.0010
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1052e-04 - r2: -94.5108 - val_loss: 3.7451e-04 - val_r2: -120.5573 - learning_rate: 0.0010
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9858e-04 - r2: -94.9210 - val_loss: 3.5973e-04 - val_r2: -116.4199 - learning_rate: 0.0010
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8916e-04 - r2: -94.6917 - val_loss: 3.4054e-04 - val_r2: -112.4050 - learning_rate: 0.0010
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8885e-04 - r2: -94.7126 - val_loss: 3.4130e-04 - val_r2: -111.3983 - learning_rate: 0.0010
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6899e-04 - r2: -94.6968 - val_loss: 3.1985e-04 - val_r2: -107.4004 - learning_rate: 0.0010
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5929e-04 - r2: -94.4493 - val_loss: 3.0918e-04 - val_r2: -106.1130 - learning_rate: 0.0010
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4045e-04 - r2: -94.7137 - val_loss: 3.0250e-04 - val_r2: -104.9038 - learning_rate: 0.0010
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6230e-04 - r2: -94.9269 - val_loss: 2.9995e-04 - val_r2: -104.5285 - learning_rate: 0.0010
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4303e-04 - r2: -94.8977 - val_loss: 3.2928e-04 - val_r2: -108.9581 - learning_rate: 0.0010
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6155e-04 - r2: -95.0060 - val_loss: 2.9648e-04 - val_r2: -103.3587 - learning_rate: 0.0010
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3775e-04 - r2: -94.5895 - val_loss: 3.1797e-04 - val_r2: -105.5813 - learning_rate: 0.0010
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4945e-04 - r2: -94.4122 - val_loss: 2.9522e-04 - val_r2: -102.9326 - learning_rate: 1.0000e-04
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4766e-04 - r2: -94.7205 - val_loss: 2.9070e-04 - val_r2: -102.3914 - learning_rate: 1.0000e-04
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4019e-04 - r2: -94.9175 - val_loss: 2.9527e-04 - val_r2: -102.8485 - learning_rate: 1.0000e-04
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3395e-04 - r2: -94.7221 - val_loss: 2.8412e-04 - val_r2: -101.7002 - learning_rate: 1.0000e-04
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3748e-04 - r2: -94.6784 - val_loss: 2.9066e-04 - val_r2: -102.3395 - learning_rate: 1.0000e-04
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2479e-04 - r2: -94.6980 - val_loss: 2.8503e-04 - val_r2: -101.6659 - learning_rate: 1.0000e-04
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5263e-04 - r2: -94.6823 - val_loss: 2.8687e-04 - val_r2: -101.8260 - learning_rate: 1.0000e-04
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3108e-04 - r2: -94.8127 - val_loss: 2.8522e-04 - val_r2: -101.6938 - learning_rate: 1.0000e-04
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4153e-04 - r2: -94.8147 - val_loss: 2.8302e-04 - val_r2: -101.7249 - learning_rate: 1.0000e-04
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3401e-04 - r2: -94.9123 - val_loss: 2.8238e-04 - val_r2: -101.5119 - learning_rate: 1.0000e-04
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2828e-04 - r2: -94.9635 - val_loss: 2.8346e-04 - val_r2: -101.5169 - learning_rate: 1.0000e-04
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3873e-04 - r2: -94.8442 - val_loss: 2.9186e-04 - val_r2: -102.2419 - learning_rate: 1.0000e-04
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3305e-04 - r2: -94.7017 - val_loss: 2.8191e-04 - val_r2: -101.3075 - learning_rate: 1.0000e-04
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3535e-04 - r2: -94.6679 - val_loss: 2.8797e-04 - val_r2: -101.8819 - learning_rate: 1.0000e-04
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3871e-04 - r2: -94.4600 - val_loss: 2.9445e-04 - val_r2: -102.5081 - learning_rate: 1.0000e-04
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4241e-04 - r2: -94.2252 - val_loss: 2.8608e-04 - val_r2: -101.5802 - learning_rate: 1.0000e-05
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3295e-04 - r2: -94.6143 - val_loss: 2.8270e-04 - val_r2: -101.2651 - learning_rate: 1.0000e-05
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4151e-04 - r2: -94.5374 - val_loss: 2.8246e-04 - val_r2: -101.2514 - learning_rate: 1.0000e-05
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3273e-04 - r2: -94.7766 - val_loss: 2.8310e-04 - val_r2: -101.3261 - learning_rate: 1.0000e-05
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3178e-04 - r2: -94.4833 - val_loss: 2.8176e-04 - val_r2: -101.2065 - learning_rate: 1.0000e-05
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3958e-04 - r2: -94.7579 - val_loss: 2.8301e-04 - val_r2: -101.3081 - learning_rate: 1.0000e-05
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3341e-04 - r2: -94.8051 - val_loss: 2.8177e-04 - val_r2: -101.2033 - learning_rate: 1.0000e-05
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3377e-04 - r2: -94.7509 - val_loss: 2.8222e-04 - val_r2: -101.2457 - learning_rate: 1.0000e-05
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4514e-04 - r2: -94.7216 - val_loss: 2.8212e-04 - val_r2: -101.2374 - learning_rate: 1.0000e-05
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4589e-04 - r2: -94.7558 - val_loss: 2.8212e-04 - val_r2: -101.2390 - learning_rate: 1.0000e-05
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3134e-04 - r2: -94.6626 - val_loss: 2.8229e-04 - val_r2: -101.2554 - learning_rate: 1.0000e-05
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4273e-04 - r2: -94.7026 - val_loss: 2.8259e-04 - val_r2: -101.2986 - learning_rate: 1.0000e-05
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4276e-04 - r2: -94.5387 - val_loss: 2.8239e-04 - val_r2: -101.2834 - learning_rate: 1.0000e-05
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4809e-04 - r2: -94.5949 - val_loss: 2.8201e-04 - val_r2: -101.2530 - learning_rate: 1.0000e-05
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2385e-04 - r2: -94.6877 - val_loss: 2.8195e-04 - val_r2: -101.2452 - learning_rate: 1.0000e-05

# %%
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='Validation_loss')
plt.legend()

# %%
plt.plot(history.history['r2'], label='training')
plt.plot(history.history['val_r2'], label='Validation')
plt.legend()

# %%
predictions = model.predict(test_data_x)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
Predictions = []
for i in range(len(predictions)):
    Predictions.append(predictions[i]*(trg_max-trg_min)+trg_min)

# %%
results = {'date' : stock_with_sentiment_data.date[limiter+WINDOW_SIZE:],
           'original': stock_with_sentiment_data.target_close[limiter+WINDOW_SIZE:],
          'predictions':Predictions
          }
df_results = pd.DataFrame(results) 
df_results.date = pd.to_datetime(df_results.date)
df_results.index = df_results.date

fig, ax = plt.subplots(figsize=(8,4))
ax.set_facecolor('#FFFFFF')
ax.plot(df_results['original'], color='dodgerblue', label='Original price')
plt.plot(df_results['predictions'], color='orangered', label='Predicted price')
plt.title('Test data vs prediction for close price all data')
plt.legend()

# %%
df_results = df_results[:-1]

# %%
r2 = r2_score(df_results['original'], df_results['predictions'])
mse = mean_squared_error(df_results['original'], df_results['predictions'])
mae = mean_absolute_error(df_results['original'], df_results['predictions'])
rmse = np.sqrt(mse)
print('R2 score is -> ', r2)
print('RMSE is -> ', rmse)
# Out:
# R2 score is ->  0.9389587862736827
# RMSE is ->  5.999643159526304

# %%
df_results
# Out:
#                  date    original           predictions
# date
# 2023-11-09 2023-11-09  186.399994   [181.4025474676746]
# 2023-11-10 2023-11-10  186.399994  [182.28923311373364]
# 2023-11-11 2023-11-11  186.399994  [183.54923835182035]
# 2023-11-12 2023-11-12  184.800003  [185.56399465291997]
# 2023-11-13 2023-11-13  187.440002    [186.183680933289]
# ...               ...         ...                   ...
# 2025-04-25 2025-04-25  209.279999   [204.2151890562027]
# 2025-04-26 2025-04-26  209.279999  [205.94649579372617]
# 2025-04-27 2025-04-27  210.139999  [207.15721703814597]
# 2025-04-28 2025-04-28  211.210007  [207.90597410192913]
# 2025-04-29 2025-04-29  212.500000  [208.97967252395665]
#
# [538 rows x 3 columns]

# %%
df_results.dtypes
# Out:
# date           datetime64[ns]
# original              float64
# predictions            object
# dtype: object

# %%
df_results['predictions'] = df_results['predictions'].apply(lambda x: x[0])

# %%
df_results
# Out:
#                  date    original  predictions
# date
# 2023-11-09 2023-11-09  186.399994   181.402547
# 2023-11-10 2023-11-10  186.399994   182.289233
# 2023-11-11 2023-11-11  186.399994   183.549238
# 2023-11-12 2023-11-12  184.800003   185.563995
# 2023-11-13 2023-11-13  187.440002   186.183681
# ...               ...         ...          ...
# 2025-04-25 2025-04-25  209.279999   204.215189
# 2025-04-26 2025-04-26  209.279999   205.946496
# 2025-04-27 2025-04-27  210.139999   207.157217
# 2025-04-28 2025-04-28  211.210007   207.905974
# 2025-04-29 2025-04-29  212.500000   208.979673
#
# [538 rows x 3 columns]

# %%
df_results['original_prev'] = df_results['original'].shift(1)

# %%
df_results
# Out:
#                  date    original  predictions  original_prev
# date
# 2023-11-09 2023-11-09  186.399994   181.402547            NaN
# 2023-11-10 2023-11-10  186.399994   182.289233     186.399994
# 2023-11-11 2023-11-11  186.399994   183.549238     186.399994
# 2023-11-12 2023-11-12  184.800003   185.563995     186.399994
# 2023-11-13 2023-11-13  187.440002   186.183681     184.800003
# ...               ...         ...          ...            ...
# 2025-04-25 2025-04-25  209.279999   204.215189     209.279999
# 2025-04-26 2025-04-26  209.279999   205.946496     209.279999
# 2025-04-27 2025-04-27  210.139999   207.157217     209.279999
# 2025-04-28 2025-04-28  211.210007   207.905974     210.139999
# 2025-04-29 2025-04-29  212.500000   208.979673     211.210007
#
# [538 rows x 4 columns]

# %%
# Вычисляем дельты (направление движения)
df_results['true_diff'] = df_results['original'] - df_results['original_prev']
df_results['pred_diff'] = df_results['predictions'] - df_results['original_prev']

# %%
df_results
# Out:
#                  date    original  predictions  original_prev  true_diff  \
# date
# 2023-11-09 2023-11-09  186.399994   181.402547            NaN        NaN
# 2023-11-10 2023-11-10  186.399994   182.289233     186.399994   0.000000
# 2023-11-11 2023-11-11  186.399994   183.549238     186.399994   0.000000
# 2023-11-12 2023-11-12  184.800003   185.563995     186.399994  -1.599991
# 2023-11-13 2023-11-13  187.440002   186.183681     184.800003   2.639999
# ...               ...         ...          ...            ...        ...
# 2025-04-25 2025-04-25  209.279999   204.215189     209.279999   0.000000
# 2025-04-26 2025-04-26  209.279999   205.946496     209.279999   0.000000
# 2025-04-27 2025-04-27  210.139999   207.157217     209.279999   0.860001
# 2025-04-28 2025-04-28  211.210007   207.905974     210.139999   1.070007
# 2025-04-29 2025-04-29  212.500000   208.979673     211.210007   1.289993
#
#             pred_diff
# date
# 2023-11-09        NaN
# 2023-11-10  -4.110761
# 2023-11-11  -2.850756
# 2023-11-12  -0.835999
# 2023-11-13   1.383678
# ...               ...
# 2025-04-25  -5.064810
# 2025-04-26  -3.333503
# 2025-04-27  -2.122782
# 2025-04-28  -2.234025
# 2025-04-29  -2.230334
#
# [538 rows x 6 columns]

# %%
df_results['correct_direction'] = np.sign(df_results['true_diff']) == np.sign(df_results['pred_diff'])
accuracy = df_results['correct_direction'].iloc[1:].mean()
print(f"Accuracy предсказанного направления движения цены: {accuracy:.2%}")
# Out:
# Accuracy предсказанного направления движения цены: 35.01%
